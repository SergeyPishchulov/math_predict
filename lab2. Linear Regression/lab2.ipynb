# %%
! python -m pip install ipywidgets
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from app import  *

# %%
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8      y
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64
#
# [768 rows x 9 columns]

# %%
plot_corr()

# %% [markdown]
# ### Стастическая значимость факторов

# %%
alpha_slider
# Out:
# FloatSlider(value=0.05, continuous_update=False, description='Уровень α :', max=0.2, step=0.001)

# %%
get_conf_df(alpha_slider.value)
# Out:
#     left border  right border  t_statistic
# X1       -23.59        -16.50       -11.10
# X2        -0.01         -0.00        -2.91
# X3         0.02          0.04         8.50
# X4        -0.02         -0.01        -7.35
# X5         4.86          5.74        23.63
# X6        -0.20          0.17        -0.17
# X7        18.34         21.58        24.23
# X8         0.07          0.35         2.92

# %% [markdown]
# ### Отбор значимых факторов

# %%
feature_checkboxes= [Checkbox(value=False, description=f) for f in x.columns]
output = widgets.VBox(children=feature_checkboxes)
display(output)

# %%
chosen_features = [cb.description for cb in feature_checkboxes if cb.value]
chosen_features
# Out:
# ['X2']
